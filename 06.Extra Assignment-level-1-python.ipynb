# %%
#print Statement
print("HOPE AI")
# Out:
# HOPE AI

# %%
#Buy inputs
input("Enter your institute Name :")
# Out:
# ''

# %%
#Buy inputs
print(input("Enter your Name :"))
print(input("Enter your Age :"))
print(input("Enter your School Name :"))
print(input("Enter your Degree :"))

# %%
#Addition
Num1= 43
Num2= 34
print(Num1+Num2)
# Out:
# 77

# %%
#Subtraction
Num1= 20
Num2= 10
print(Num1-Num2)
# Out:
# 10

# %%
#Multiplication
Num1= 5
Num2= 5
print(Num1*Num2)
# Out:
# 25

# %%
#Division
Num1= 36
Num2= 7
print(Num1/Num2)
# Out:
# 5.142857142857143

# %%
#Floor Division (Gives Only Quotient)
Num1= 65
Num2= 30
print(Num1//Num2)
# Out:
# 2

# %%
#Modulo (Gives Only Reminder)
Num1= 10
Num2= 6
print(Num1%Num2)
# Out:
# 4

# %%
#Power
Num1 = 3
Num2 = 3

result = pow(Num1, Num2)
print(result)
# Out:
# 27
